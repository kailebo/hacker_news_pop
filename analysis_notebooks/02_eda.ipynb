# %% [markdown]
# # Next steps
# Divide data into two catagories:
# - Post attibrutes: These are elements of the element that are intrinsic to the item itself and not other reaction to it
#     - id
#     - user
#     - title
#     - url
#     - type
#     - time
#     - text
# - Preformance attributes: These are elements of the item the reflect people's recation to it on the site
#     - comments: kids, descendants
#     - rank
#     - score
#
# In this analysis we are interested in how trends in Post attibrutes corrilate to Preformance attributes

# %% [markdown]
# w
